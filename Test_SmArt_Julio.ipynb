# %% [markdown]
# <a href="https://colab.research.google.com/github/disney-snoopy/SmArtGenerative/blob/master/Test_SmArt_Julio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
1 + 1
# Out:
# 2

# %%
# One line to see what happens
